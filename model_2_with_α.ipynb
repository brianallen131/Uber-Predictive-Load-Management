# %%
import pandas as pd
from datetime import datetime
import numpy as np
import os
import math as m
from pulp import *


def uber_utility(W_uber, P_uber):
        
    return 14 - 1.2*W_uber - 9*(P_uber-1) 

def subway_utility(W_sub, P_sub):
    
    return 6 - 0.9*W_sub

def probability(W_uber, P_uber, W_sub, P_sub, theta):
    denom = m.exp(uber_utility(W_uber, P_uber)/theta) + m.exp(subway_utility(W_sub, P_sub)/theta)
    probability = m.exp(uber_utility(W_uber, P_uber)/theta)/denom
        
    return probability


surge = 1.5
P_uber = (12.03 - 3) * surge
P_sub = 3
theta = 2
W_sub = 7

d_1_2 = 6.86
d_1_3 = 10.78
d_2_3 = 8.56

def Get_x_ij(surge, W_sub, P_sub, theta):
    x_ij = [[0,0,0],[0,0,0],[0,0,0]]
    x_ij[0][0] = probability(0, surge, W_sub, P_sub, theta)
    x_ij[1][1] = probability(0, surge, W_sub, P_sub, theta)
    x_ij[2][2] = probability(0, surge, W_sub, P_sub, theta)

    x_ij[0][1] = probability(d_1_2, surge, W_sub, P_sub, theta)
    x_ij[1][0] = probability(d_1_2, surge, W_sub, P_sub, theta)

    x_ij[0][2] = probability(d_1_3, surge, W_sub, P_sub, theta)
    x_ij[2][0] = probability(d_1_3, surge, W_sub, P_sub, theta)

    x_ij[1][2] = probability(1.25*d_1_2, surge, W_sub, P_sub, theta)
    x_ij[2][1] = probability(1.25*d_1_2, surge, W_sub, P_sub, theta)
    return x_ij

# %%
#no reallocation
# model 2
OptimalOutput =0
for z in range(101):
# ========= SET-UP =========== #
    NUM_AREA = 3
    R = 13.54 # Revenue
    S = 1.5 # Multiplier
    alpha = 0.01*z
    
    # ========== DATA ============= #
    x_ij= Get_x_ij(surge, W_sub, P_sub, theta)
    c_ij = [[0, 4.146 ,999], [4.146, 0, 999],[6.51,5.18,0]] # c00, c01, c10, c11

    d_i = [100, 20,0] # d_1, d_2
    n_0i = [5, 44,10000] # n_01, n_02

    # ========= INIT LP ============ #
    prob = LpProblem("Model", LpMaximize)

    m_ij = [[0]*NUM_AREA for _ in range(NUM_AREA)]
    y_ij = [[0]*NUM_AREA for _ in range(NUM_AREA)]
    n_1i = []
    for i in range(NUM_AREA):
        n_1i.append(LpVariable("n_1%d"%(i), 0, None, LpInteger))
        for j in range(NUM_AREA):
            y_ij[i][j] = LpVariable("y_%d%d"%(i,j), 0, None, LpInteger)
            if i!=j:
                m_ij[i][j] = LpVariable("m_%d%d"%(i,j), 0, None, LpInteger)

    # ========= CONSTRUCT LP ============ #

    # Objective
    prob += sum([alpha*S*R*y_ij[i][j]*x_ij[i][j] - (1-alpha)*m_ij[i][j]*c_ij[i][j] for i in range(NUM_AREA) for j in range(NUM_AREA)])

    # Subject To
    for j in range(NUM_AREA):
        # n_1i
        prob += n_1i[j] == n_0i[j] + sum(m_ij[i][j] for i in range(NUM_AREA)) - sum(m_ij[j][i] for i in range(NUM_AREA)), "Equation Area: %d"%j
        # n_0i
        prob += n_0i[j] >= sum(m_ij[j][i] for i in range(NUM_AREA)), "Moving Constrain: %d"%j
        # y_ij
        prob += sum(y_ij[j][i] for i in range(NUM_AREA)) <= d_i[j] ,"Total Demand: %d"%j
        prob += sum(y_ij[i][j]*x_ij[i][j] for i in range(NUM_AREA)) <= n_1i[j] ,"Total Available: %d"%j


# ============== SOLVE ============= #
    print ("")
    
    prob.solve()    
    print("==========-1-1-1-1-=========")
    print("alpha =" + str(alpha))
    print("\n == Optimal Variables == \n")
    for v in prob.variables():
        if v.name == "n_10":
            print (v.name, "=", v.varValue)
    print("Objective: " ,value(prob.objective))
    print("==========-1-1-1-===========")
    

# iterate for x_11 probability within region 1 or 2
# Out:
# ==========-1-1-1-1-=========
# alpha =0.0
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  0.0
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.01
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  12.801463261896782
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.02
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  25.602926523793563
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.03
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  38.40438978569035
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.04
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  51.20585304758713
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.05
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  64.00731630948391
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.06
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  76.8087795713807
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.07
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  89.61024283327748
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.08
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  102.41170609517425
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.09
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  115.21316935707105
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.1
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  128.01463261896782
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.11
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  140.8160958808646
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.12
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  153.6175591427614
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.13
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  166.41902240465816
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.14
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  179.22048566655496
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.15
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  192.0219489284517
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.16
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  204.8234121903485
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.17
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  217.6248754522453
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.18
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  230.4263387141421
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.19
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  243.2278019760389
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.2
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  256.02926523793565
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.21
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  268.8307284998324
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.22
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  281.6321917617292
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.23
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  294.43365502362605
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.24
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  307.2351182855228
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.25
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  320.0966938682243
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.26
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  334.8927740078062
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.27
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  351.75788070041415
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.28
#
#  == Optimal Variables ==
#
# n_10 = 5.0
# Objective:  368.6229873930222
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.29
#
#  == Optimal Variables ==
#
# n_10 = 7.0
# Objective:  385.90458774619395
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.3
#
#  == Optimal Variables ==
#
# n_10 = 7.0
# Objective:  403.2330218064076
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.31
#
#  == Optimal Variables ==
#
# n_10 = 7.0
# Objective:  420.56145586662115
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.32
#
#  == Optimal Variables ==
#
# n_10 = 11.0
# Objective:  440.211801064336
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.33
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  464.83183564191376
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.34
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  490.7540124795476
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.35000000000000003
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  516.6761893171814
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.36
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  542.598366154815
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.37
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  568.5205429924488
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.38
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  594.4427198300826
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.39
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  620.3648966677163
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.4
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  646.2870735053501
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.41000000000000003
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  672.2092503429839
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.42
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  698.1314271806175
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.43
#
#  == Optimal Variables ==
#
# n_10 = 65.0
# Objective:  724.0536040182515
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.44
#
#  == Optimal Variables ==
#
# n_10 = 78.0
# Objective:  750.0543113577647
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.45
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  779.6907009460722
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.46
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  809.4996943004294
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.47000000000000003
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  839.3086876547866
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.48
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  869.1176810091437
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.49
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  898.9266743635008
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.5
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  928.735667717858
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.51
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  958.5446610722151
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.52
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  988.3536544265723
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.53
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1018.1626477809294
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.54
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1047.9716411352865
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.55
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1077.7806344896437
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.56
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1107.589627844001
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.5700000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1137.3986211983581
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.58
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1167.2076145527149
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.59
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1197.0166079070723
# ==========-1-1-1-===========
# ==========-1-1-1-1-=========
# alpha =0.6
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1226.8256012614295
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.61
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1256.6345946157867
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.62
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1286.4435879701439
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.63
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1316.252581324501
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.64
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1346.0615746788583
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.65
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1375.8705680332155
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.66
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1405.6795613875724
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.67
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1435.48855474193
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.68
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1465.2975480962864
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.6900000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1495.1065414506438
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.7000000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1524.9155348050012
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.71
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1554.724528159358
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.72
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1584.5335215137154
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.73
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1614.3425148680724
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.74
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1644.1515082224294
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.75
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1673.9605015767866
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.76
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1703.7694949311442
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.77
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1733.5784882855014
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.78
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1763.387481639858
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.79
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1793.1964749942154
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.8
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1823.005468348573
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.81
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1852.8144617029302
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.8200000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1882.623455057287
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.8300000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1912.4324484116444
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.84
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1942.241441766001
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.85
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  1972.0504351203583
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.86
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2001.8594284747157
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.87
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2031.6684218290727
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.88
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2061.4774151834295
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.89
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2091.2864085377864
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.9
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2121.0954018921443
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.91
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2150.9043952465013
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.92
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2180.713388600859
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.93
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2210.5223819552157
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.9400000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2240.331375309573
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.9500000000000001
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2270.14036866393
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.96
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2299.949362018287
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.97
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2329.758355372644
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.98
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2359.5673487270014
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =0.99
#
#  == Optimal Variables ==
#
# n_10 = 100.0
# Objective:  2389.376342081358
# ==========-1-1-1-===========
#
# ==========-1-1-1-1-=========
# alpha =1.0
#
#  == Optimal Variables ==
#
# n_10 = 10029.0
# Objective:  2419.185335435716
# ==========-1-1-1-===========
